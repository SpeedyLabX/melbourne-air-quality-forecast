# %% [markdown]
# # Melbourne Air Quality Historical Data Collection
# # Research Notebook for Environmental Analysis

# %% [markdown]
# ## Overview
# This notebook fetches historical air quality data from the OpenWeatherMap API for EPA Victoria air monitoring station locations across Melbourne. The data is collected for research purposes to analyze air quality trends and patterns in the Melbourne metropolitan area.
#
# ### Key Features:
# - **Comprehensive Coverage**: 20+ monitoring locations across Melbourne
# - **Secure API Key Management**: Environment variable integration
# - **Robust Error Handling**: Comprehensive error management and logging
# - **Research-Ready Output**: Clean CSV format with proper metadata
# - **Progress Tracking**: Real-time progress monitoring with tqdm

# %% [markdown]
# ## 1. Environment Setup and Dependencies

# %%
# =============================================================================
# CELL 1: SETUP, IMPORTS, AND LOGGER CONFIGURATION
# =============================================================================
"""
Melbourne Air Quality Data Collection System
===========================================

This notebook collects historical air quality data from OpenWeatherMap API
for EPA Victoria monitoring station locations across Melbourne.

Author: Research Team
Date: 2025
Purpose: Environmental air quality analysis and research
"""

import os
import sys
import requests
import csv
import time
import logging
from datetime import datetime, timedelta
from typing import Dict, List, Tuple, Any
from tqdm.notebook import tqdm
from dotenv import load_dotenv
import pandas as pd

# --- 1. UTF-8 Aware Logger Setup (CRUCIAL FIX) ---
def setup_logger(log_file='logs/01_air_quality_melbourne_data_collection.log', level=logging.INFO):
    """Configures a logger to be UTF-8 aware for both console and file output."""
    logger = logging.getLogger()
    logger.setLevel(level)
    
    # Prevents adding duplicate handlers if you re-run this cell
    if logger.hasHandlers():
        logger.handlers.clear()

    # Console Handler with explicit UTF-8 encoding
    console_handler = logging.StreamHandler(sys.stdout)
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console_handler.setFormatter(console_formatter)
    
    # File Handler with explicit UTF-8 encoding
    file_handler = logging.FileHandler(log_file, mode='w', encoding='utf-8')
    file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(file_formatter)

    # Add both handlers to the root logger
    logger.addHandler(console_handler)
    logger.addHandler(file_handler)
    
    return logger

# --- 2. Initialize Environment ---
# Load environment variables from .env file
load_dotenv()

# Initialize the logger for use throughout the notebook
logger = setup_logger()

logger.info("📊 Melbourne Air Quality Data Collection System")
logger.info("=" * 50)
logger.info("🔬 Research Environment Initialized")
logger.info("📋 Dependencies loaded and UTF-8 logger configured.")
# Out:
# 2025-06-20 11:57:24,268 - INFO - 📊 Melbourne Air Quality Data Collection System
# 2025-06-20 11:57:24,269 - INFO - ==================================================
# 2025-06-20 11:57:24,271 - INFO - 🔬 Research Environment Initialized
# 2025-06-20 11:57:24,272 - INFO - 📋 Dependencies loaded and UTF-8 logger configured.

# %% [markdown]
# ## 2. Configuration and Research Parameters

# %%
# =============================================================================
# CELL 2: RESEARCH CONFIGURATION
# =============================================================================

class AirQualityConfig:
    """Configuration class for air quality data collection."""
    
    def __init__(self):
        # API Configuration
        self.API_KEY = os.getenv('OPENWEATHER_API_KEY')
        if not self.API_KEY:
            logger.critical("❌ OpenWeather API key not found in .env file. Halting.")
            raise ValueError("API key not configured.")
        
        self.BASE_URL = "http://api.openweathermap.org/data/2.5/air_pollution/history"
        
        # Research Period
        self.START_DATE = datetime(2020, 11, 25)
        self.END_DATE = datetime(2025, 1, 4)
        
        # Data Collection Parameters
        self.CHUNK_SIZE_DAYS = 5
        self.REQUEST_DELAY_SECONDS = 0.5
        self.REQUEST_TIMEOUT = 20  # seconds
        
        # Output Configuration
        self.OUTPUT_CSV_PATH = f"../data/raw/melbourne_raw_air_quality_{self.START_DATE.strftime('%Y%m%d')}_to_{self.END_DATE.strftime('%Y%m%d')}.csv"
        self.LOG_FILE_PATH = "air_quality_collection.log"
        
        # EPA Victoria Air Monitoring Stations & Representative Locations
        self.MONITORING_LOCATIONS = {
            "Melbourne CBD": [-37.8136, 144.9631], 
            "Footscray": [-37.7997, 144.9020],
            "Brooklyn": [-37.8161, 144.8415], 
            "Alphington": [-37.7833, 145.0333],
            "Spotswood": [-37.8335, 144.8863], 
            "Box Hill": [-37.8185, 145.1225],
            "Brighton": [-37.9056, 145.0028], 
            "Dandenong": [-37.9875, 145.2149],
            "Mooroolbark": [-37.7825, 145.3168], 
            "Altona North": [-37.8410, 144.8490],
            "Melton": [-37.6833, 144.5833], 
            "Point Cook": [-37.9148, 144.7509],
            "Macleod": [-37.7333, 145.0667], 
            "Carlton": [-37.8001, 144.9656],
            "Richmond": [-37.8183, 145.0014], 
            "St Kilda": [-37.8676, 144.9801],
            "Yarraville": [-37.8167, 144.9000], 
            "Frankston": [-38.1421, 145.1256],
            "Ringwood": [-37.8136, 145.2306], 
            "Werribee": [-37.9009, 144.6590],
            "Craigieburn": [-37.5986, 144.9425], 
            "Pakenham": [-38.0753, 145.4834],
            "Broadmeadows": [-37.6839, 144.9169],
        }
        
        # CSV Headers - *Corrected to match processing function*
        self.CSV_HEADERS = [
            "location", "latitude", "longitude", "datetime", "timestamp_unix",
            "aqi", "co", "no", "no2", "o3", "so2", "pm2_5", "pm10", "nh3"
        ]

# --- Initialize configuration ---
try:
    config = AirQualityConfig()
    logger.info(f"🎯 Research Configuration Loaded")
    logger.info(f"📍 Monitoring {len(config.MONITORING_LOCATIONS)} locations")
    logger.info(f"💾 Output file will be: {config.OUTPUT_CSV_PATH}")
    logger.info(f"🔑 API key configured: ✅")
except ValueError as e:
    logger.error("Could not initialize configuration.")
# Out:
# 2025-06-20 11:57:27,340 - INFO - 🎯 Research Configuration Loaded
# 2025-06-20 11:57:27,341 - INFO - 📍 Monitoring 23 locations
# 2025-06-20 11:57:27,342 - INFO - 💾 Output file will be: ../data/raw/melbourne_air_quality_20201125_to_20250104.csv
# 2025-06-20 11:57:27,342 - INFO - 🔑 API key configured: ✅

# %% [markdown]
# ## 3. Data Collection Functions

# %%
# =============================================================================
# CELL 3: CORE DATA COLLECTION CLASS
# =============================================================================

class AirQualityDataCollector:
    """Handles the mechanics of fetching, processing, and writing data."""
    
    def __init__(self, config: AirQualityConfig):
        self.config = config
        self.session = requests.Session()
        self.total_records = 0
        self.failed_requests = 0
        
    def fetch_historical_data(
        self, location: str, lat: float, lon: float, start_unix: int, end_unix: int
    ) -> List[Dict]:
        """Fetches and enhances historical data for a single API call."""
        params = {
            "lat": lat, "lon": lon, "start": start_unix, "end": end_unix, "appid": self.config.API_KEY
        }
        try:
            response = self.session.get(self.config.BASE_URL, params=params, timeout=self.config.REQUEST_TIMEOUT)
            response.raise_for_status()
            raw_data = response.json().get("list", [])
            logger.info(f"✅ API call for {location} successful. Retrieved {len(raw_data)} records.")
            return [{**entry, 'location': location, 'latitude': lat, 'longitude': lon} for entry in raw_data]
        except requests.exceptions.HTTPError as e:
            logger.error(f"❌ HTTP Error {e.response.status_code} for {location}: {e.response.text}")
        except requests.exceptions.RequestException as e:
            logger.error(f"❌ Request failed for {location}: {e}")
        
        self.failed_requests += 1
        return []

    def _process_to_csv_row(self, entry: Dict) -> List:
        """Processes a single JSON data point into a list for CSV writing."""
        dt_object = datetime.fromtimestamp(entry["dt"])
        components = entry.get("components", {})
        main_data = entry.get("main", {})
        
        # Ensure the row matches the headers defined in config
        return [
            entry.get('location', ''), entry.get('latitude', ''), entry.get('longitude', ''),
            dt_object.strftime("%Y-%m-%d %H:%M:%S"), entry["dt"],
            main_data.get("aqi", ''), components.get("co", ''), components.get("no", ''),
            components.get("no2", ''), components.get("o3", ''), components.get("so2", ''),
            components.get("pm2_5", ''), components.get("pm10", ''), components.get("nh3", '')
        ]

    def _collect_for_location(self, writer: csv.writer, location: str, lat: float, lon: float) -> int:
        """Handles the data collection loop for a single location."""
        records_for_location = 0
        current_date = self.config.START_DATE
        while current_date <= self.config.END_DATE:
            start_unix = int(current_date.timestamp())
            end_date_for_chunk = min(current_date + timedelta(days=self.config.CHUNK_SIZE_DAYS), self.config.END_DATE + timedelta(days=1))
            end_unix = int(end_date_for_chunk.timestamp())
            
            data_points = self.fetch_historical_data(location, lat, lon, start_unix, end_unix)
            for entry in data_points:
                writer.writerow(self._process_to_csv_row(entry))
                records_for_location += 1
            
            current_date = end_date_for_chunk
            time.sleep(self.config.REQUEST_DELAY_SECONDS)
        return records_for_location

    def collect_all_data(self) -> Tuple[bool, int]:
        """Orchestrates the entire data collection process."""
        logger.info("🚀 Starting comprehensive air quality data collection...")
        self.total_records = 0
        self.failed_requests = 0
        
        try:
            with open(self.config.OUTPUT_CSV_PATH, mode="w", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow(self.config.CSV_HEADERS)
                location_progress = tqdm(self.config.MONITORING_LOCATIONS.items(), desc="🌍 Processing Locations", unit="location")
                for location, (lat, lon) in location_progress:
                    location_progress.set_postfix_str(f"📍 {location}")
                    self.total_records += self._collect_for_location(writer, location, lat, lon)
            return True, self.total_records
        except IOError as e:
            logger.critical(f"💥 CRITICAL FILE ERROR: Could not write to {self.config.OUTPUT_CSV_PATH}. Reason: {e}")
            return False, 0
        except Exception as e:
            logger.critical(f"💥 UNEXPECTED CRITICAL ERROR during collection: {e}")
            return False, 0

# --- Initialize the collector ---
collector = AirQualityDataCollector(config)
logger.info("🔧 Data collector class defined and instance created.")
# Out:
# 2025-06-20 11:57:33,796 - INFO - 🔧 Data collector class defined and instance created.

# %% [markdown]
# ## 4. Execute Data Collection

# %%
# =============================================================================
# CELL 4: DATA COLLECTION ORCHESTRATOR
# =============================================================================

def _print_results_summary(start_time: datetime, end_time: datetime, total_records: int):
    """Logs the summary of the data collection results."""
    duration = end_time - start_time
    logger.info("=" * 60)
    logger.info("✅ DATA COLLECTION COMPLETED SUCCESSFULLY!")
    logger.info(f"📁 Data saved to: {config.OUTPUT_CSV_PATH}")
    logger.info(f"📊 Total records collected: {total_records}")
    logger.info(f"⏱️  Total duration: {duration}")
    if duration.total_seconds() > 0:
        logger.info(f"🎯 Collection efficiency: {total_records / duration.total_seconds():.2f} records/second")

def _print_final_guidance(success: bool):
    """Prints helpful next steps or troubleshooting advice to the console."""
    if success:
        print("\n🎉 Ready for research and analysis! See logs for details.")
    else:
        print("\n❌ DATA COLLECTION FAILED. Check the log file for detailed error information.")

def run_data_collection_pipeline() -> bool:
    """Orchestrates the entire data collection process."""
    logger.info(f"🕐 Collection started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    start_time = datetime.now()
    
    success, total_records = collector.collect_all_data()
    
    end_time = datetime.now()
    
    if success:
        _print_results_summary(start_time, end_time, total_records)
    
    return success

# --- Execute the Pipeline ---
was_successful = run_data_collection_pipeline()
_print_final_guidance(was_successful)
# Out:
# 2025-06-20 11:57:36,308 - INFO - 🕐 Collection started at: 2025-06-20 11:57:36
# 2025-06-20 11:57:36,310 - INFO - 🚀 Starting comprehensive air quality data collection...
# 🌍 Processing Locations:   0%|          | 0/23 [00:00<?, ?location/s]
# 2025-06-20 11:57:36,861 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 113 records.
# 2025-06-20 11:57:37,779 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:38,700 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:39,611 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:40,524 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:41,432 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:42,345 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:43,257 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:44,170 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:45,085 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:46,010 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:46,925 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:47,640 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 11:57:48,548 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:49,465 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:50,376 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:51,287 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:52,197 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:53,112 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:54,026 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:54,958 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:55,893 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:56,808 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:57,732 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:58,642 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:57:59,553 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:00,463 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:01,391 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:02,311 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:03,221 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:04,132 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:05,045 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:05,956 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:06,875 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:07,794 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:08,726 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:09,649 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:10,561 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:11,470 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:12,377 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:13,289 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:14,196 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:15,103 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:16,017 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:16,928 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:17,840 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:18,757 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:19,667 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:20,592 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:21,509 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:22,422 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:23,333 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:24,246 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:25,157 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:26,069 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:26,984 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:27,913 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:28,824 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:29,736 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:30,639 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:31,556 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:32,476 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:33,389 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:34,293 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:35,198 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:36,111 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:37,014 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:37,922 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:38,833 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:39,740 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:40,656 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:41,572 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:42,480 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:43,384 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:44,296 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:45,213 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:46,121 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:47,044 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:47,952 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:48,877 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:49,789 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:50,706 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:51,615 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:52,525 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:53,450 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 11:58:54,357 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 113 records.
# 2025-06-20 11:58:55,279 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:56,193 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:57,121 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:58,034 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:58:58,920 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 11:58:59,827 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:00,737 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:01,663 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:02,573 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:03,488 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:04,406 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:05,321 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:06,243 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:07,157 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:08,075 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:08,992 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:09,896 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:10,806 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:11,697 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 11:59:12,612 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:13,541 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:14,454 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:15,377 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:16,294 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:17,202 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:18,121 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:19,052 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:19,974 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:20,891 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:21,793 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:22,708 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:23,627 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:24,534 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:25,442 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:26,320 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 73 records.
# 2025-06-20 11:59:27,234 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:28,136 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:29,050 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:29,961 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:30,879 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:31,789 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:32,706 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:33,615 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:34,525 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:35,446 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:36,363 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:37,298 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:38,207 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:39,118 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:40,021 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:40,937 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:41,852 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:42,754 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:43,671 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:44,578 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:45,493 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:46,396 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:47,311 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:48,217 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:49,127 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:50,041 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:50,963 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:51,869 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 11:59:52,756 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 89 records.
# 2025-06-20 11:59:53,665 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:54,591 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:55,481 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 11:59:56,397 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:57,307 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:58,210 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 11:59:59,124 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:00,026 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:00,936 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:01,868 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:02,787 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:03,692 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:04,595 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:05,508 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:06,381 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 73 records.
# 2025-06-20 12:00:07,289 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 12:00:08,191 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 113 records.
# 2025-06-20 12:00:09,118 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:10,025 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:10,939 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:11,853 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:12,755 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:13,671 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:14,593 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:15,502 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:16,410 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:17,397 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:18,308 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:19,225 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:20,135 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:21,050 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:21,954 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:22,857 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:23,761 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:24,683 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:25,610 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:26,530 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:27,439 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:28,362 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:29,272 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:30,184 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:31,095 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:32,004 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:32,889 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 12:00:33,795 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:34,710 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:35,626 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:36,531 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:37,436 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:38,351 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:39,242 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:40,148 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:41,054 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:41,941 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:42,844 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:43,749 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:44,460 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 73 records.
# 2025-06-20 12:00:45,357 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 12:00:46,235 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 89 records.
# 2025-06-20 12:00:47,137 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:48,050 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:48,957 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:49,877 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:50,783 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:51,704 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:52,608 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:53,494 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:54,393 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:55,300 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:56,205 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:57,117 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:58,008 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:00:59,378 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:00,478 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:01,667 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:02,693 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:03,556 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:04,416 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:05,119 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 12:01:05,979 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:06,860 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:07,741 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:08,608 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:09,474 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:10,364 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:11,274 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:12,157 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:13,061 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:13,962 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:14,879 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:15,783 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:16,702 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:17,603 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:18,491 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:19,395 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:20,272 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 97 records.
# 2025-06-20 12:01:21,198 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:22,084 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:22,976 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:23,895 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:24,779 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:25,673 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:26,576 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:27,478 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:28,379 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:29,282 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:30,186 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:31,101 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:31,988 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:32,890 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 12:01:33,775 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 113 records.
# 2025-06-20 12:01:34,662 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:35,584 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:36,477 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:37,385 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:38,295 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:39,182 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:40,062 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 73 records.
# 2025-06-20 12:01:40,974 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:41,860 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:42,763 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:43,648 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:44,556 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:45,501 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:46,402 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:47,291 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:48,174 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 104 records.
# 2025-06-20 12:01:49,091 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 113 records.
# 2025-06-20 12:01:50,014 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:50,915 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:51,822 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:52,727 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:53,613 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:54,586 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:55,494 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:56,401 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:57,294 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:58,191 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:01:59,091 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:00,058 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:00,947 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:01,854 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:02,962 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:03,854 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:04,746 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:05,654 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:06,542 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:07,456 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:08,362 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:09,284 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 121 records.
# 2025-06-20 12:02:10,039 - INFO - ✅ API call for Melbourne CBD successful. Retrieved 49 records.
# 2025-06-20 12:02:10,939 - INFO - ✅ API call for Footscray successful. Retrieved 113 records.
# 2025-06-20 12:02:11,821 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:12,716 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:13,600 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:14,483 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:15,368 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:16,253 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:17,141 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:18,023 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:18,907 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:19,811 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:20,724 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:23,080 - INFO - ✅ API call for Footscray successful. Retrieved 97 records.
# 2025-06-20 12:02:23,999 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:24,880 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:25,801 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:26,738 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:27,657 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:28,575 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:29,486 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:30,373 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:31,266 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:32,170 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:33,054 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:33,957 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:34,859 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:35,744 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:36,661 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:37,544 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:38,471 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:39,379 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:40,280 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:41,183 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:42,084 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:42,988 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:43,903 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:44,814 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:45,730 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:46,635 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:47,554 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:48,457 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:49,371 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:50,273 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:51,183 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:52,064 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:52,965 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:53,882 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:54,762 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:55,676 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:56,599 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:57,500 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:58,404 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:02:59,284 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:00,211 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:01,095 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:02,904 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:04,130 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:05,014 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:05,933 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:06,867 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:07,786 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:08,942 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:09,830 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:10,720 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:12,214 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:13,105 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:14,001 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:14,895 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:15,780 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:16,670 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:17,556 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:18,444 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:19,331 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:20,223 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:21,108 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:22,002 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:22,888 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:23,783 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:24,672 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:25,559 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:26,468 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:27,371 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:28,257 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:29,146 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:30,055 - INFO - ✅ API call for Footscray successful. Retrieved 104 records.
# 2025-06-20 12:03:30,958 - INFO - ✅ API call for Footscray successful. Retrieved 113 records.
# 2025-06-20 12:03:31,863 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:32,751 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:33,655 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:34,552 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:35,413 - INFO - ✅ API call for Footscray successful. Retrieved 97 records.
# 2025-06-20 12:03:36,298 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:37,204 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:38,113 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:39,329 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:40,214 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:41,100 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:42,006 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:42,893 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:43,788 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:44,703 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:45,609 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:46,493 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:47,403 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:48,291 - INFO - ✅ API call for Footscray successful. Retrieved 97 records.
# 2025-06-20 12:03:49,198 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:50,093 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:51,003 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:51,924 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:52,817 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:53,742 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:54,247 - WARNING - Retrying (Retry(total=0, connect=None, read=False, redirect=None, status=None)) after connection broken by 'MustRedialError('Server unexpectedly closed the connection in-flight (connection dropped)')': /data/2.5/air_pollution/history?lat=-37.7997&lon=144.902&start=1654189200&end=1654621200&appid=679e74452dd7d0670ac64bcc8a98629b
# 2025-06-20 12:03:54,700 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:55,588 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:56,501 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:57,390 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:58,288 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:03:59,202 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:00,100 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:00,983 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:01,871 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:02,732 - INFO - ✅ API call for Footscray successful. Retrieved 73 records.
# 2025-06-20 12:04:03,615 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:04,523 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:05,424 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:05,930 - WARNING - Retrying (Retry(total=0, connect=None, read=False, redirect=None, status=None)) after connection broken by 'MustRedialError('Server unexpectedly closed the connection in-flight (connection dropped)')': /data/2.5/air_pollution/history?lat=-37.7997&lon=144.902&start=1659805200&end=1660237200&appid=679e74452dd7d0670ac64bcc8a98629b
# 2025-06-20 12:04:06,342 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:07,272 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:08,163 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:09,070 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:09,956 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:10,862 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:11,777 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:12,666 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:13,582 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:14,505 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:15,435 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:16,356 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:17,264 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:18,186 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:19,107 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:20,015 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:21,020 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:21,940 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:22,826 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:23,747 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:24,665 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:25,572 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:26,480 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:27,367 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:28,256 - INFO - ✅ API call for Footscray successful. Retrieved 104 records.
# 2025-06-20 12:04:29,119 - INFO - ✅ API call for Footscray successful. Retrieved 89 records.
# 2025-06-20 12:04:30,009 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:30,981 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:31,844 - INFO - ✅ API call for Footscray successful. Retrieved 97 records.
# 2025-06-20 12:04:32,730 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:33,619 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:34,517 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:35,413 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:36,309 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:37,205 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:38,118 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:39,016 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:39,928 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:40,827 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:41,713 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:42,574 - INFO - ✅ API call for Footscray successful. Retrieved 73 records.
# 2025-06-20 12:04:43,493 - INFO - ✅ API call for Footscray successful. Retrieved 104 records.
# 2025-06-20 12:04:44,386 - INFO - ✅ API call for Footscray successful. Retrieved 113 records.
# 2025-06-20 12:04:45,275 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:46,215 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:47,123 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:48,033 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:48,965 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:49,882 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:50,787 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:51,694 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:52,617 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:53,552 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:54,491 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:55,393 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:56,295 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:57,236 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:58,159 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:04:59,091 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:00,017 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:00,965 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:01,899 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:02,800 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:03,710 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:04,642 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:05,542 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:06,477 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# 2025-06-20 12:05:07,406 - INFO - ✅ API call for Footscray successful. Retrieved 121 records.
# ...
# 2025-06-20 13:42:36,733 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:37,650 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:38,587 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:39,538 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:40,458 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:41,374 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:42,295 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:43,208 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:44,118 - INFO - ✅ API call for Broadmeadows successful. Retrieved 104 records.
# 2025-06-20 13:42:45,011 - INFO - ✅ API call for Broadmeadows successful. Retrieved 89 records.
# 2025-06-20 13:42:45,921 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:46,847 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:47,733 - INFO - ✅ API call for Broadmeadows successful. Retrieved 97 records.
# 2025-06-20 13:42:48,657 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:49,624 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:50,540 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:51,454 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:52,400 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:53,312 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:54,227 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:55,151 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:56,062 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:56,985 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:57,904 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:42:58,789 - INFO - ✅ API call for Broadmeadows successful. Retrieved 73 records.
# 2025-06-20 13:42:59,707 - INFO - ✅ API call for Broadmeadows successful. Retrieved 104 records.
# 2025-06-20 13:43:00,706 - INFO - ✅ API call for Broadmeadows successful. Retrieved 113 records.
# 2025-06-20 13:43:01,633 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:02,552 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:03,491 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:04,402 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:05,314 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:06,254 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:07,166 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:08,095 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:09,013 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:09,951 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:10,864 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:11,832 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:12,756 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:13,673 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:14,594 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:15,529 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:16,447 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:17,363 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:18,281 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:19,195 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:20,116 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:21,041 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:21,958 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:22,868 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:23,793 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:24,713 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:25,602 - INFO - ✅ API call for Broadmeadows successful. Retrieved 97 records.
# 2025-06-20 13:43:26,522 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:27,439 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:28,359 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:29,275 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:30,187 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:31,104 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:32,016 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:32,935 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:34,166 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:35,087 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:36,006 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:36,924 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:37,807 - INFO - ✅ API call for Broadmeadows successful. Retrieved 73 records.
# 2025-06-20 13:43:38,728 - INFO - ✅ API call for Broadmeadows successful. Retrieved 104 records.
# 2025-06-20 13:43:39,622 - INFO - ✅ API call for Broadmeadows successful. Retrieved 89 records.
# 2025-06-20 13:43:40,531 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:41,460 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:42,377 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:43,297 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:44,210 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:45,142 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:46,073 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:46,998 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:47,910 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:48,833 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:49,752 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:50,683 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:51,600 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:52,517 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:53,448 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:54,365 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:55,279 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:56,199 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:57,121 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:58,027 - INFO - ✅ API call for Broadmeadows successful. Retrieved 97 records.
# 2025-06-20 13:43:58,943 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:43:59,862 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:00,782 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:01,695 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:02,606 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:03,592 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:04,507 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:05,409 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:06,336 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:07,297 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:08,296 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:09,324 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:10,219 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:11,133 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:12,051 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:12,966 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:13,844 - INFO - ✅ API call for Broadmeadows successful. Retrieved 97 records.
# 2025-06-20 13:44:14,755 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:15,663 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:16,563 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:17,456 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:18,352 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:19,262 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:20,160 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:21,079 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:21,994 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:22,951 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:23,853 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:24,746 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:25,663 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:26,592 - INFO - ✅ API call for Broadmeadows successful. Retrieved 104 records.
# 2025-06-20 13:44:27,511 - INFO - ✅ API call for Broadmeadows successful. Retrieved 113 records.
# 2025-06-20 13:44:28,418 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:29,322 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:30,603 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:31,529 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:32,510 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:33,413 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:34,302 - INFO - ✅ API call for Broadmeadows successful. Retrieved 73 records.
# 2025-06-20 13:44:35,193 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:36,117 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:37,047 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:37,955 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:38,857 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:39,803 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:40,732 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:41,666 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:42,572 - INFO - ✅ API call for Broadmeadows successful. Retrieved 104 records.
# 2025-06-20 13:44:43,464 - INFO - ✅ API call for Broadmeadows successful. Retrieved 113 records.
# 2025-06-20 13:44:44,367 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:45,292 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:46,185 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:47,092 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:48,029 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:48,940 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:49,951 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:50,862 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:51,770 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:52,666 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:53,571 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:54,480 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:55,393 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:56,318 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:57,260 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:58,175 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:44:59,119 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:00,020 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:00,919 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:01,839 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:02,754 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:03,919 - INFO - ✅ API call for Broadmeadows successful. Retrieved 121 records.
# 2025-06-20 13:45:04,640 - INFO - ✅ API call for Broadmeadows successful. Retrieved 49 records.
# 2025-06-20 13:45:05,146 - INFO - ============================================================
# 2025-06-20 13:45:05,151 - INFO - ✅ DATA COLLECTION COMPLETED SUCCESSFULLY!
# 2025-06-20 13:45:05,154 - INFO - 📁 Data saved to: ../data/raw/melbourne_air_quality_20201125_to_20250104.csv
# 2025-06-20 13:45:05,158 - INFO - 📊 Total records collected: 823009
# 2025-06-20 13:45:05,160 - INFO - ⏱️  Total duration: 1:47:28.835997
# 2025-06-20 13:45:05,162 - INFO - 🎯 Collection efficiency: 127.62 records/second
#
# 🎉 Ready for research and analysis! See logs for details.

# %% [markdown]
# ## 5. Data Analysis and Validation

# %%
# =============================================================================
# CELL 5: DATA ANALYSIS AND VALIDATION
# =============================================================================

def analyze_collected_data():
    """Perform initial analysis and validation of the collected data CSV."""
    if not os.path.exists(config.OUTPUT_CSV_PATH):
        logger.error(f"❌ No data file found at '{config.OUTPUT_CSV_PATH}'. Please run data collection first.")
        return None
    
    logger.info(f"📊 Analyzing collected data from '{config.OUTPUT_CSV_PATH}'...")
    try:
        df = pd.read_csv(config.OUTPUT_CSV_PATH)
        
        print("\n--- Data Analysis Report ---")
        print(f"📈 Dataset Overview:")
        print(f"   - Total records: {len(df):,}")
        print(f"   - Unique Locations: {df['location'].nunique()}")
        
        print(f"\n📍 Location Coverage (Top 10):")
        print(df['location'].value_counts().head(10))
        
        print(f"\n🔬 Data Completeness per Parameter:")
        for param in ['aqi', 'pm2_5', 'pm10', 'no2', 'o3', 'co', 'so2']:
            if param in df.columns:
                percentage = df[param].notna().mean() * 100
                print(f"   - {param.upper()}: {percentage:.1f}% complete")
        
        print(f"\n✅ Data Quality Checks:")
        print(f"   - Duplicate rows: {df.duplicated().sum()}")
        print(f"   - Rows with missing timestamps: {df['datetime'].isnull().sum()}")
        print("--- End of Report ---")
        
        return df
    except Exception as e:
        logger.error(f"❌ Analysis failed: {e}")
        return None

# --- Run the analysis on the generated file ---
# You can re-run this cell anytime after the collection is complete.
df_analysis = analyze_collected_data()
if df_analysis is not None:
    print("\nDataFrame returned to 'df_analysis' variable. You can now use it for further work.")
    # display(df_analysis.head()) # Uncomment to see the first few rows
# Out:
# 2025-06-20 13:45:57,700 - INFO - 📊 Analyzing collected data from '../data/raw/melbourne_air_quality_20201125_to_20250104.csv'...
#
# --- Data Analysis Report ---
# 📈 Dataset Overview:
#    - Total records: 823,009
#    - Unique Locations: 23
#
# 📍 Location Coverage (Top 10):
# Melbourne CBD    35783
# Macleod          35783
# Pakenham         35783
# Craigieburn      35783
# Werribee         35783
# Ringwood         35783
# Frankston        35783
# Yarraville       35783
# St Kilda         35783
# Richmond         35783
# Name: location, dtype: int64
#
# 🔬 Data Completeness per Parameter:
#    - AQI: 100.0% complete
#    - PM2_5: 100.0% complete
#    - PM10: 100.0% complete
#    - NO2: 100.0% complete
#    - O3: 100.0% complete
#    - CO: 100.0% complete
#    - SO2: 100.0% complete
#
# ✅ Data Quality Checks:
#    - Duplicate rows: 6762
#    - Rows with missing timestamps: 0
# --- End of Report ---
#
# DataFrame returned to 'df_analysis' variable. You can now use it for further work.

# %% [markdown]
# This notebook provides:
#
# 1. **Professional Structure**: Clear markdown sections with research context
# 2. **Environment Variables**: Secure API key management with `.env` file
# 3. **Expanded Coverage**: Based on EPA Victoria's monitoring network including Melbourne CBD, Footscray, Brooklyn, and portable monitoring locations like Box Hill, Brighton, Dandenong, Mooroolbark, Altona North, Melton, Point Cook, and Macleod
# 4. **Research Features**:
#    - Comprehensive logging
#    - Error handling
#    - Progress tracking
#    - Data validation
#    - Analysis functions
# 5. **Professional Output**: Clean CSV with metadata and research documentation
#
# To use this notebook:
#
# 1. Create a `.env` file with your OpenWeather API key:
# ```
# OPENWEATHER_API_KEY=your_actual_api_key_here
# ```
#
# 2. Install required packages:
# ```bash
# pip install requests tqdm python-dotenv pandas numpy
# ```
#
# 3. Run the notebook cells in order to collect and analyze your air quality data.
#
# The notebook covers 22 monitoring locations across Melbourne, including official EPA monitoring stations and representative locations for comprehensive coverage of the metropolitan area.
